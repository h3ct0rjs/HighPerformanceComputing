# %% [markdown]
# # Accelerating Python code with Libraries on GPUs
#
# In this self-paced, hands-on lab, we will use GPU libraries to accelerate Python code on NVIDIA GPUs.
#
# Lab created by Mark Ebersole (Follow [@CUDAHamster](https://twitter.com/@cudahamster) on Twitter)

# %% [markdown]
# The following timer counts down to a five minute warning before the lab instance shuts down.  You should get a pop up at the five minute warning reminding you to save your work!

# %% [markdown]
# <script src="files/countdown_v5.0/countdown.js"></script>
# <div id="clock" align="center"></div>
# <script>
# myDate = new Date();
# curTime = Date.UTC(myDate.getUTCFullYear(),
#                    myDate.getUTCMonth(),
#                    myDate.getUTCDate(),
#                    myDate.getUTCHours(),
#                    myDate.getUTCMinutes(),
#                    myDate.getUTCSeconds(),
#                    myDate.getUTCMilliseconds());
#
# function countdownComplete(){
#   	alert("You only have five minutes left in the lab! Time to save your work - see the Post Lab section near the bottom.");
# }
# var myCD = new Countdown({
#                          time  	: (1507747473681+50*60000-curTime)/1000,
#                          target	 	: "clock",
#                          onComplete	: countdownComplete,
#                          rangeHi  : "minute",
#                          hideLine	: true,
#                          hideLabels	: false,
#                          height	 	: 60,
#                          width     : 150,
#                          style     : "boring",
#                     });
#  </script>

# %% [markdown]
# ---
# Before we begin, let's verify [WebSockets](http://en.wikipedia.org/wiki/WebSocket) are working on your system.  To do this, execute the cell block below by giving it focus (clicking on it with your mouse), and hitting Ctrl-Enter, or pressing the play button in the toolbar above.  If all goes well, you should see get some output returned below the grey cell.  If not, please consult the [Self-paced Lab Troubleshooting FAQ](https://developer.nvidia.com/self-paced-labs-faq#Troubleshooting) to debug the issue.

# %%
print "The answer should be three: " + str(1+2)
# Out:
# The answer should be three: 3

# %% [markdown]
# Let's execute the cell below to display information about the GPUs running on the server.

# %%
# !nvidia-smi
# Out:
# Wed Oct 11 19:21:52 2017
# +------------------------------------------------------+
# | NVIDIA-SMI 340.29     Driver Version: 340.29         |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GRID K520           On   | 0000:00:03.0     Off |                  N/A |
# | N/A   37C    P8    17W / 125W |     10MiB /  4095MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Compute processes:                                               GPU Memory |
# |  GPU       PID  Process name                                     Usage      |
# |=============================================================================|
# |  No running compute processes found                                         |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ---
# <p class="hint_trigger">If you have never before taken an IPython Notebook based self-paced lab from NVIDIA, click this green box.
#       <div class="toggle_container"><div class="input_area box-flex1"><div class=\"highlight\">The following video will explain the infrastructure we are using for this self-paced lab, as well as give some tips on it's usage.  If you've never taken a lab on this system before, it's highly encourage you watch this short video first.<br><br>
# <div align="center"><iframe width="640" height="390" src="http://www.youtube.com/embed/ZMrDaLSFqpY" frameborder="0" allowfullscreen></iframe></div>
# <br>
# <h2 style="text-align:center;color:red;">Attention Firefox Users</h2><div style="text-align:center; margin: 0px 25px 0px 25px;">There is a bug with Firefox related to setting focus in any text editors embedded in this lab. Even though the cursor may be blinking in the text editor, focus for the keyboard may not be there, and any keys you press may be applying to the previously selected cell.  To work around this issue, you'll need to first click in the margin of the browser window (where there are no cells) and then in the text editor.  Sorry for this inconvenience, we're working on getting this fixed.</div></div></div></div></p>

# %% [markdown]
# ## Introduction to GPU Libraries
#
# Let's get started! The following Python code is a simple Monte Carlo pricer in which the step function has been vectorized using the NumbaPro compiler to run on the GPU.  Without modifying the code, execute and verify the cell runs successfully - select the cell with your mouse and use Ctrl-Enter or the Play button on the toolbar to do this.
#
# **NOTE:** The point of this lab will focus on the implementation of the `montecarlo` function only.  However, we'll be using code imported from a mc.py file which includes the `driver` and GPU-accelerated `step` function.  While it's not necessary to see or understand this code, there is a cell located at the bottom of this lab that will show you the code if you're interested, although I encourage you to finish the lab first.
#
# You can also consult the <a href="#FAQ">FAQ</a> located at the bottom of this page.

# %%
from mc import *  # Import our support functions

# Inputs:
#   paths - a 100x3000000 array to store the 100 time steps of prices for each 3,000,000 paths
#   dt - A constant value needed in the Monte Carlo algorithm
#   interest - A constant value needed in the Monte Carlo algorithm
#   volatility - A constant value needed in the Monte Carlo algorithm
def montecarlo(paths, dt, interest, volatility):
    # c0 and c1 are two constants we need for the step calculation
    c0 = interest - 0.5 * volatility ** 2
    c1 = volatility * np.sqrt(dt)
    
    for j in xrange(1, paths.shape[1]):   # for each time step
        prices = paths[:, j - 1]          # last set of prices
        # Generate gaussian noises for simulation
        noises = np.random.normal(0., 1., prices.size)
        # Call the GPU-acclereated step function to calculate the next set of prices
        paths[:, j] = step(prices, dt, c0, c1, noises)

driver(montecarlo, do_plot=True) # Call the driver function to start the calcuations
# Out:
# Result
#          stock price: 22.6401589293
#       standard error: 0.000177214965664
#             paid off: 1.14016372517
#         option price: 1.0490012671
# Performance
#         Mstep/second: 14.10
#         time elapsed: 21.284s
# Plotting 50/3000000 paths
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days

# %% [markdown]
# When looking to speed-up code by moving portions to an accelerator, it's very important not to guess at what you think should be optimized first.  When I first looked at this code, I assumed the bottleneck would be data transfer across the PCI-Express bus before and after the `step` function was executed on the GPU.
#
# Now, while guessing that data movement is the main bottleneck to performance in our code is a good guess, it's better to profile the code and see what's really going on.  It's an all too common mistake for people to spend lots of time trying to optimize the wrong piece of code.  Let's not make that same mistake, and we'll use some handy Python tools to profile our code.
#
# We're going to use [cProfile](http://docs.python.org/2/library/profile.html#module-cProfile) to do this.  Given how simple this is, you won't have to do any work other than just executing the below cell.

# %%
import cProfile as profile
profile.run("driver(montecarlo)", sort="time")
# Out:
# Result
#          stock price: 22.6401859936
#       standard error: 0.000177136892979
#             paid off: 1.14019022639
#         option price: 1.04902564941
# Performance
#         Mstep/second: 14.10
#         time elapsed: 21.271s
#          144420 function calls (141420 primitive calls) in 21.325 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       100   16.476    0.165   16.476    0.165 {method 'normal' of 'mtrand.RandomState' objects}
#      3700    3.248    0.001    3.252    0.001 driver.py:212(safe_cuda_api_call)
#         1    1.125    1.125   21.271   21.271 <ipython-input-3-9f43facf81ea>:8(montecarlo)
#      1200    0.055    0.000    0.060    0.000 ndarray.py:110(make_array_ctype)
#      1205    0.043    0.000    0.043    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.025    0.025   21.319   21.319 mc.py:25(driver)
# 11600/8600    0.017    0.000    0.020    0.000 {getattr}
#       600    0.017    0.000    0.457    0.001 devicearray.py:55(__init__)
#       600    0.017    0.000    0.182    0.000 ndarray.py:141(ndarray_populate_head)
#       600    0.013    0.000    0.063    0.000 dummyarray.py:157(__init__)
#       600    0.012    0.000    0.160    0.000 driver.py:506(memalloc)
#       600    0.009    0.000    0.087    0.000 ndarray.py:94(write)
#      1200    0.009    0.000    0.039    0.000 fromnumeric.py:2259(prod)
#       100    0.008    0.000    3.655    0.037 deviceufunc.py:165(call)
#         1    0.007    0.007    0.013    0.013 _methods.py:77(_var)
#         1    0.007    0.007   21.325   21.325 <string>:1(<module>)
#       100    0.006    0.000    3.670    0.037 dispatch.py:25(__call__)
#      2400    0.005    0.000    0.022    0.000 driver.py:1284(device_ctypes_pointer)
#       905    0.005    0.000    0.005    0.000 {numpy.core.multiarray.array}
#       300    0.005    0.000    0.008    0.000 stride_tricks.py:23(as_strided)
#      1200    0.005    0.000    0.005    0.000 ndarray.py:115(c_array)
#      1900    0.005    0.000    0.018    0.000 devices.py:114(_get_device)
#       600    0.005    0.000    0.070    0.000 dummyarray.py:148(from_desc)
#      4926    0.005    0.000    0.005    0.000 {isinstance}
#       100    0.005    0.000    0.945    0.009 devicearray.py:156(copy_to_host)
#       600    0.004    0.000    0.013    0.000 dummyarray.py:184(_compute_extent)
#      3700    0.004    0.000    0.004    0.000 driver.py:241(_check_error)
#      1100    0.004    0.000    2.200    0.002 driver.py:1318(host_to_device)
#      5400    0.004    0.000    0.009    0.000 driver.py:857(__getattr__)
#       600    0.004    0.000    0.054    0.000 driver.py:669(cleanup)
#       600    0.004    0.000    0.029    0.000 ndarray.py:78(allocate)
#       600    0.004    0.000    0.010    0.000 contextlib.py:21(__exit__)
#      1900    0.004    0.000    0.023    0.000 devices.py:122(get_context)
#       600    0.004    0.000    0.004    0.000 utils.py:129(__setitem__)
#      3800    0.004    0.000    0.004    0.000 threadlocal.py:13(stack)
#       600    0.004    0.000    0.005    0.000 dummyarray.py:167(_compute_layout)
#      1900    0.003    0.000    0.009    0.000 threadlocal.py:36(__bool__)
#      1200    0.003    0.000    0.014    0.000 ndarray.py:67(get_stage)
#      1200    0.003    0.000    0.003    0.000 {numba.mviewbuf.memoryview_get_buffer}
#       600    0.003    0.000    0.057    0.000 driver.py:285(process)
#       100    0.003    0.000    0.013    0.000 deviceufunc.py:100(_broadcast)
#       200    0.003    0.000    0.003    0.000 {method '__reduce_ex__' of 'object' objects}
#       500    0.003    0.000    0.374    0.001 devicearray.py:317(from_array_like)
#       500    0.003    0.000    2.152    0.004 devicearray.py:142(copy_to_device)
#      4100    0.003    0.000    0.012    0.000 driver.py:1290(is_device_memory)
#      2000    0.003    0.000    0.003    0.000 {zip}
#      1800    0.003    0.000    0.021    0.000 driver.py:1279(device_pointer)
#       100    0.003    0.000    0.013    0.000 driver.py:1069(launch_kernel)
#       100    0.003    0.000    0.006    0.000 deviceufunc.py:27(_fill_arrays)
#      1900    0.002    0.000    0.005    0.000 threadlocal.py:32(is_empty)
#       600    0.002    0.000    2.633    0.004 devices.py:134(_require_cuda_context)
#       600    0.002    0.000    0.002    0.000 driver.py:727(__init__)
#       600    0.002    0.000    0.003    0.000 contextlib.py:82(helper)
#      1200    0.002    0.000    0.007    0.000 dummyarray.py:108(compute_index)
#       600    0.002    0.000    0.003    0.000 ndarray.py:38(__new__)
#      1200    0.002    0.000    0.007    0.000 driver.py:1246(host_pointer)
#       500    0.002    0.000    2.540    0.005 dispatch.py:203(to_device)
#       600    0.002    0.000    0.005    0.000 driver.py:846(__del__)
#       100    0.002    0.000    0.005    0.000 deviceufunc.py:50(_resolve_signature)
#       100    0.002    0.000    0.003    0.000 api.py:134(_fill_stride_by_order)
#      1900    0.002    0.000    0.011    0.000 threadlocal.py:39(__nonzero__)
#      2400    0.002    0.000    0.011    0.000 driver.py:1301(require_device_memory)
#      3500    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#      1900    0.002    0.000    0.003    0.000 threadlocal.py:28(top)
#      6400    0.002    0.000    0.002    0.000 {len}
#      2400    0.002    0.000    0.003    0.000 dummyarray.py:109(<genexpr>)
#       100    0.002    0.000    0.002    0.000 deviceufunc.py:16(__init__)
#       500    0.002    0.000    2.528    0.005 api.py:23(to_device)
#       600    0.002    0.000    0.003    0.000 driver.py:1262(memory_size_from_info)
#       200    0.002    0.000    0.003    0.000 copy.py:306(_reconstruct)
#       100    0.002    0.000    0.022    0.000 compiler.py:247(_kernel_call)
#       600    0.002    0.000    0.003    0.000 driver.py:745(own)
#       600    0.001    0.000    0.001    0.000 dummyarray.py:27(__init__)
#      1200    0.001    0.000    0.030    0.000 _methods.py:34(_prod)
#       600    0.001    0.000    0.059    0.000 service.py:18(service)
#       600    0.001    0.000    0.001    0.000 driver.py:837(__init__)
#      1200    0.001    0.000    0.004    0.000 {sum}
#       600    0.001    0.000    0.001    0.000 {numba.mviewbuf.memoryview_get_extents_info}
#       600    0.001    0.000    0.002    0.000 ndarray.py:89(free)
#       600    0.001    0.000    0.003    0.000 compiler.py:298(_prepare_args)
#       100    0.001    0.000    0.005    0.000 api.py:121(_prepare_shape_strides_dtype)
#      1100    0.001    0.000    0.006    0.000 dispatch.py:200(is_device_array)
#      1900    0.001    0.000    0.001    0.000 devices.py:77(context)
#       600    0.001    0.000    0.007    0.000 driver.py:910(query)
#       500    0.001    0.000    0.001    0.000 {numba.mviewbuf.memoryview_get_extents}
#       600    0.001    0.000    0.003    0.000 devicearray.py:136(device_ctypes_pointer)
#       600    0.001    0.000    0.003    0.000 driver.py:748(free)
#       600    0.001    0.000    0.003    0.000 devicearray.py:118(__del__)
#       600    0.001    0.000    0.010    0.000 contextlib.py:15(__enter__)
#       600    0.001    0.000    0.002    0.000 driver.py:668(core)
#       600    0.001    0.000    0.004    0.000 driver.py:1308(device_memory_depends)
#       200    0.001    0.000    0.008    0.000 copy.py:66(copy)
#      1100    0.001    0.000    0.005    0.000 devicearray.py:22(is_cuda_ndarray)
#      1200    0.001    0.000    0.001    0.000 {_weakref.proxy}
#       100    0.001    0.000    0.007    0.000 compiler.py:111(configure)
#      2400    0.001    0.000    0.001    0.000 driver.py:777(device_ctypes_pointer)
#       600    0.001    0.000    0.004    0.000 driver.py:924(record)
#       100    0.001    0.000    0.031    0.000 plugins.py:84(__call__)
#       800    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x7feb285c54c0}
#       100    0.001    0.000    0.027    0.000 deviceufunc.py:130(get_arguments)
#      1200    0.001    0.000    0.058    0.000 {next}
#       600    0.001    0.000    0.002    0.000 <string>:8(__new__)
#       100    0.001    0.000    0.092    0.001 api.py:63(device_array)
#      1200    0.001    0.000    0.001    0.000 dummyarray.py:80(get_offset)
#       600    0.001    0.000    0.005    0.000 numeric.py:394(asarray)
#       600    0.001    0.000    0.001    0.000 driver.py:664(mem_finalize)
#       100    0.001    0.000    0.001    0.000 deviceufunc.py:140(get_function)
#       500    0.001    0.000    0.003    0.000 driver.py:1272(host_memory_size)
#       100    0.001    0.000    0.939    0.009 driver.py:1336(device_to_host)
#       600    0.001    0.000    0.001    0.000 dummyarray.py:172(is_contig)
#      1100    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#       100    0.001    0.000    0.001    0.000 {numpy.core.multiarray.empty}
#       100    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      1200    0.001    0.000    0.001    0.000 dummyarray.py:160(<genexpr>)
#       600    0.001    0.000    0.001    0.000 driver.py:663(_make_mem_finalizer)
#      1200    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#       600    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#       101    0.001    0.000    0.001    0.000 {max}
#       500    0.001    0.000    0.001    0.000 {min}
#       100    0.001    0.000    0.032    0.000 dispatch.py:206(launch)
#       600    0.001    0.000    0.001    0.000 driver.py:738(__del__)
#       600    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#       100    0.001    0.000    0.096    0.001 dispatch.py:209(device_array)
#       600    0.001    0.000    0.001    0.000 driver.py:282(add_trash)
#       100    0.001    0.000    0.001    0.000 deviceufunc.py:42(_fill_argtypes)
#       100    0.001    0.000    0.002    0.000 deviceufunc.py:91(_get_actual_args)
#       500    0.001    0.000    0.002    0.000 driver.py:1257(host_memory_extents)
#       100    0.001    0.000    0.003    0.000 driver.py:1017(configure)
#       200    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#       600    0.000    0.000    0.001    0.000 devicearray.py:338(auto_device)
#      1200    0.000    0.000    0.000    0.000 {_ctypes.sizeof}
#       100    0.000    0.000    0.023    0.000 compiler.py:222(__call__)
#       600    0.000    0.000    0.000    0.000 contextlib.py:12(__init__)
#      1200    0.000    0.000    0.000    0.000 dummyarray.py:161(<genexpr>)
#       600    0.000    0.000    0.000    0.000 {_ctypes.byref}
#      1200    0.000    0.000    0.000    0.000 dummyarray.py:104(is_contiguous)
#      1200    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       100    0.000    0.000    0.001    0.000 compiler.py:180(get)
#       104    0.000    0.000    0.000    0.000 {range}
#       700    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       100    0.000    0.000    0.013    0.000 driver.py:1034(__call__)
#       300    0.000    0.000    0.000    0.000 stride_tricks.py:19(__init__)
#       100    0.000    0.000    0.006    0.000 compiler.py:108(copy)
#       100    0.000    0.000    0.001    0.000 plugins.py:50(forall)
#       500    0.000    0.000    0.000    0.000 deviceufunc.py:105(<lambda>)
#       600    0.000    0.000    0.000    0.000 devicearray.py:124(_default_stream)
#       205    0.000    0.000    0.000    0.000 {hasattr}
#       600    0.000    0.000    0.000    0.000 devicearray.py:217(as_cuda_arg)
#       600    0.000    0.000    0.000    0.000 {_ctypes.addressof}
#       200    0.000    0.000    0.000    0.000 copy_reg.py:92(__newobj__)
#       600    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       100    0.000    0.000    0.000    0.000 plugins.py:77(__init__)
#       200    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         3    0.000    0.000    0.009    0.003 _methods.py:53(_mean)
#       300    0.000    0.000    0.000    0.000 {iter}
#        16    0.000    0.000    0.000    0.000 iostream.py:178(write)
#         1    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#       300    0.000    0.000    0.000    0.000 deviceufunc.py:158(force_array_layout)
#       100    0.000    0.000    0.000    0.000 {all}
#        16    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#       100    0.000    0.000    0.000    0.000 plugins.py:63(_compute_thread_per_block)
#        16    0.000    0.000    0.000    0.000 {method 'decode' of 'str' objects}
#       200    0.000    0.000    0.000    0.000 {id}
#         4    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#        16    0.000    0.000    0.000    0.000 utf_8.py:15(decode)
#        16    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.013    0.013 _methods.py:123(_std)
#        16    0.000    0.000    0.000    0.000 iostream.py:88(_check_mp_mode)
#         5    0.000    0.000    0.000    0.000 numeric.py:464(asanyarray)
#        16    0.000    0.000    0.000    0.000 iostream.py:79(_is_master_process)
#         3    0.000    0.000    0.009    0.003 fromnumeric.py:2651(mean)
#        18    0.000    0.000    0.000    0.000 {time.time}
#         5    0.000    0.000    0.000    0.000 {issubclass}
#         1    0.000    0.000    0.013    0.013 fromnumeric.py:2737(std)
#        16    0.000    0.000    0.000    0.000 {posix.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# If you scroll to the top of the list of calls, the function dominating the runtime is not data movement between the device and host, it is the NumPy `random.normal` function used to generate random noise used in the `step` call.  Over half of the application runtime is spent simply generating random noise.
#
# It so happens that the GPU is extremely efficient at generating large quantities of random data very rapidly.  In fact, there even exists a handy library for doing this called [cuRAND](https://developer.nvidia.com/cuRAND).  Since we've already moved some of our execution to the GPU (the `step` function), let's try moving a little bit more over and see what kind of speedup we can get.
#
# The cuRAND library is included with the NumbaPro compiler under the numbapro.cudalib package.  Execute the below cell to import the library into our runtime.

# %%
from numbapro.cudalib import curand

# %% [markdown]
# ### Task #1
#
# Your first task in this lab is to modify the `montecarlo` function to use the cuRAND library to generate the noise values for our algorithm on the GPU.  The documentation for this in Python using NumbaPro can be found [here](http://docs.continuum.io/numbapro/cudalib.html).  There are hints provided if you get stuck, and the answer is given below for you to check your work.
#
# After you have modified the `montecarlo_curand` function below, run the application with the new function and/or use the cProfiler to see what kind of speedup has been achieved.
#
# <p class="hint_trigger">Hint #1
#     <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight">You will first use the cuRAND PRNG function to create a random number generator.</div></div></div></p>
#
# <p class="hint_trigger">Hint #2
#     <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight">For this exercise, don't worry about returning data in a CUDA Device Array; instead use a basic NumPy array.  You can create an empty one with:<pre>
# <code>noises = np.zeros(paths.shape[0], dtype=float)</code></pre></div></div></div></p>
#
# <p class="hint_trigger">Hint #3
#     <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight">Once you have a NumPy array to store the generated values in and have created a PRNG generator, use the <code>normal</code> function to actually generate the values on the GPU.</div></div></div></p>
#
# <p class="hint_trigger">Hint #4
#     <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight">There is no need to modify the <code>step</code> function call.</div></div></div></p>

# %%
def montecarlo_curand(paths, dt, interest, volatility):
    c0 = interest - 0.5 * volatility ** 2
    c1 = volatility * np.sqrt(dt)
    prng = curand.PRNG(rndtype=curand.PRNG.XORWOW)
    d_noises = np.zeros(paths.shape[0], dtype=float)
    
    for j in xrange(1, paths.shape[1]):   # for each time step
        prices = paths[:, j - 1]          # last set of prices
        # Generate gaussian noises for simulation
        
        ## TODO relace the NumPy noise generating call with a cuRAND version ##
        prng.normal(d_noises, 0., 1.)
        # Call the GPU-acclereated step function to calculate the next set of prices
        paths[:, j] = step(prices, dt, c0, c1,d_noises)

# %% [markdown]
# <p class="hint_trigger">Click to check your answer
#     <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight"><pre><code>def montecarlo_curand(paths, dt, interest, volatility):
#     c0 = interest - 0.5 &#42; volatility ** 2
#     c1 = volatility &#42; np.sqrt(dt)
#
#     prng = curand.PRNG(rndtype=curand.PRNG.XORWOW)
#     noises = np.zeros(paths.shape[0], dtype=float)
#
#     for j in xrange(1, paths.shape[1]):   # for each time step
#         prices = paths[:, j - 1]          # last set of prices
#         # Generate gaussian noises for simulation
#         prng.normal(noises, 0., 1.)
#         # Call the GPU-acclereated step function to calculate the next set of prices
#         paths[:, j] = step(prices, dt, c0, c1, noises)</code></pre></div></div></div></p>

# %% [markdown]
# After modifying and executing the cell above to add the `montecarlo_curand` function to our runtime, execute the below cell to see how it affects our Monte Carlo pricing simulation.

# %%
driver(montecarlo_curand, do_plot=True)
# Out:
# Result
#          stock price: 22.6402514162
#       standard error: 0.000177156870874
#             paid off: 1.14025634544
#         option price: 1.04908648186
# Performance
#         Mstep/second: 42.32
#         time elapsed: 7.089s
# Plotting 50/3000000 paths

# %% [markdown]
# By simply replacing the random number generator with a host side GPU library call to cuRAND, our application has achieved a major speedup.  In my case it was **9.6x** over the version we started with at the beginning of this lab, and we only added or modified four lines of code to get it.
#
# Let's now re-run the profiler and see how things have changed.

# %%
profile.run("driver(montecarlo_curand)", sort="time")
# Out:
# Result
#          stock price: 22.6402514162
#       standard error: 0.000177156870874
#             paid off: 1.14025634544
#         option price: 1.04908648186
# Performance
#         Mstep/second: 44.29
#         time elapsed: 6.773s
#          166349 function calls (163049 primitive calls) in 6.828 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4400    5.182    0.001    5.187    0.001 driver.py:212(safe_cuda_api_call)
#         1    1.091    1.091    6.772    6.772 <ipython-input-17-8c8d5e237eea>:1(montecarlo_curand)
#      1400    0.061    0.000    0.066    0.000 ndarray.py:110(make_array_ctype)
#      1405    0.047    0.000    0.047    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.026    0.026    6.821    6.821 mc.py:25(driver)
#       102    0.020    0.000    0.021    0.000 libutils.py:40(wrapped)
# 13200/9900    0.020    0.000    0.023    0.000 {getattr}
#       700    0.019    0.000    0.208    0.000 ndarray.py:141(ndarray_populate_head)
#       700    0.019    0.000    0.533    0.001 devicearray.py:55(__init__)
#       700    0.015    0.000    0.072    0.000 dummyarray.py:157(__init__)
#       700    0.013    0.000    0.191    0.000 driver.py:506(memalloc)
#      1400    0.011    0.000    0.046    0.000 fromnumeric.py:2259(prod)
#       700    0.011    0.000    0.103    0.000 ndarray.py:94(write)
#       700    0.008    0.000    0.008    0.000 utils.py:129(__setitem__)
#         1    0.008    0.008    0.013    0.013 _methods.py:77(_var)
#         1    0.007    0.007    6.828    6.828 <string>:1(<module>)
#      2900    0.007    0.000    0.029    0.000 driver.py:1284(device_ctypes_pointer)
#       100    0.006    0.000    3.451    0.035 deviceufunc.py:165(call)
#       700    0.006    0.000    0.081    0.000 dummyarray.py:148(from_desc)
#      2101    0.005    0.000    0.020    0.000 devices.py:114(_get_device)
#      4400    0.005    0.000    0.005    0.000 driver.py:241(_check_error)
#      5426    0.005    0.000    0.005    0.000 {isinstance}
#       100    0.005    0.000    3.463    0.035 dispatch.py:25(__call__)
#      1400    0.005    0.000    0.005    0.000 ndarray.py:115(c_array)
#       700    0.005    0.000    0.072    0.000 driver.py:669(cleanup)
#      1300    0.005    0.000    3.179    0.002 driver.py:1318(host_to_device)
#       200    0.005    0.000    1.884    0.009 devicearray.py:156(copy_to_host)
#       700    0.005    0.000    0.015    0.000 dummyarray.py:184(_compute_extent)
#      6200    0.005    0.000    0.011    0.000 driver.py:857(__getattr__)
#       905    0.005    0.000    0.005    0.000 {numpy.core.multiarray.array}
#      1500    0.005    0.000    0.005    0.000 {numba.mviewbuf.memoryview_get_buffer}
#       300    0.005    0.000    0.007    0.000 stride_tricks.py:23(as_strided)
#       700    0.004    0.000    0.030    0.000 ndarray.py:78(allocate)
#       700    0.004    0.000    0.011    0.000 contextlib.py:21(__exit__)
#       700    0.004    0.000    0.006    0.000 dummyarray.py:167(_compute_layout)
#      2101    0.004    0.000    0.025    0.000 devices.py:122(get_context)
#      4202    0.004    0.000    0.004    0.000 threadlocal.py:13(stack)
#      1400    0.004    0.000    0.016    0.000 ndarray.py:67(get_stage)
#      4800    0.004    0.000    0.015    0.000 driver.py:1290(is_device_memory)
#       600    0.004    0.000    0.457    0.001 devicearray.py:317(from_array_like)
#       700    0.004    0.000    0.076    0.000 driver.py:285(process)
#      2300    0.004    0.000    0.029    0.000 driver.py:1279(device_pointer)
#      2101    0.003    0.000    0.009    0.000 threadlocal.py:36(__bool__)
#       600    0.003    0.000    3.120    0.005 devicearray.py:142(copy_to_device)
#       900    0.003    0.000    0.005    0.000 devicearray.py:136(device_ctypes_pointer)
#      2300    0.003    0.000    0.003    0.000 {zip}
#       200    0.003    0.000    0.003    0.000 {method '__reduce_ex__' of 'object' objects}
#       100    0.003    0.000    0.012    0.000 deviceufunc.py:100(_broadcast)
#       100    0.003    0.000    2.214    0.022 api.py:101(normal)
#      2101    0.003    0.000    0.006    0.000 threadlocal.py:32(is_empty)
#      1500    0.003    0.000    0.009    0.000 driver.py:1246(host_pointer)
#       700    0.003    0.000    0.003    0.000 driver.py:727(__init__)
#       700    0.003    0.000    0.003    0.000 contextlib.py:82(helper)
#       700    0.003    0.000    0.007    0.000 driver.py:846(__del__)
#      1400    0.003    0.000    0.008    0.000 dummyarray.py:108(compute_index)
#       100    0.002    0.000    0.012    0.000 driver.py:1069(launch_kernel)
#       700    0.002    0.000    0.003    0.000 ndarray.py:38(__new__)
#      2900    0.002    0.000    0.012    0.000 driver.py:1301(require_device_memory)
#      2800    0.002    0.000    0.003    0.000 dummyarray.py:109(<genexpr>)
#      7100    0.002    0.000    0.002    0.000 {len}
#       601    0.002    0.000    2.488    0.004 devices.py:134(_require_cuda_context)
#      3701    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#       700    0.002    0.000    0.003    0.000 ndarray.py:89(free)
#      2101    0.002    0.000    0.011    0.000 threadlocal.py:39(__nonzero__)
#       100    0.002    0.000    0.005    0.000 deviceufunc.py:50(_resolve_signature)
#      2101    0.002    0.000    0.003    0.000 threadlocal.py:28(top)
#       100    0.002    0.000    0.007    0.000 binding.py:271(__float_or_double)
#       100    0.002    0.000    0.004    0.000 deviceufunc.py:27(_fill_arrays)
#       700    0.002    0.000    0.078    0.000 service.py:18(service)
#       700    0.002    0.000    0.004    0.000 driver.py:1262(memory_size_from_info)
#       100    0.002    0.000    0.002    0.000 api.py:134(_fill_stride_by_order)
#       700    0.002    0.000    0.002    0.000 dummyarray.py:27(__init__)
#       500    0.002    0.000    2.403    0.005 dispatch.py:203(to_device)
#       700    0.002    0.000    0.002    0.000 {numba.mviewbuf.memoryview_get_extents_info}
#       700    0.002    0.000    0.004    0.000 driver.py:745(own)
#      1400    0.002    0.000    0.035    0.000 _methods.py:34(_prod)
#       200    0.002    0.000    0.003    0.000 copy.py:306(_reconstruct)
#       100    0.002    0.000    0.002    0.000 __init__.py:498(cast)
#       700    0.002    0.000    0.002    0.000 driver.py:837(__init__)
#       600    0.002    0.000    0.002    0.000 {numba.mviewbuf.memoryview_get_extents}
#       100    0.002    0.000    0.022    0.000 compiler.py:247(_kernel_call)
#       700    0.002    0.000    0.003    0.000 driver.py:668(core)
#       700    0.002    0.000    0.004    0.000 driver.py:748(free)
#      1400    0.002    0.000    0.005    0.000 {sum}
#       700    0.002    0.000    0.004    0.000 devicearray.py:118(__del__)
#       500    0.002    0.000    2.392    0.005 api.py:23(to_device)
#       700    0.001    0.000    1.191    0.002 devicearray.py:338(auto_device)
#       700    0.001    0.000    0.007    0.000 driver.py:910(query)
#      2101    0.001    0.000    0.001    0.000 devices.py:77(context)
#       200    0.001    0.000    1.878    0.009 driver.py:1336(device_to_host)
#       600    0.001    0.000    0.003    0.000 compiler.py:298(_prepare_args)
#       700    0.001    0.000    0.011    0.000 contextlib.py:15(__enter__)
#       700    0.001    0.000    0.005    0.000 driver.py:1308(device_memory_depends)
#       100    0.001    0.000    0.004    0.000 api.py:121(_prepare_shape_strides_dtype)
#       100    0.001    0.000    0.001    0.000 api.py:32(_require_array)
#       700    0.001    0.000    0.005    0.000 driver.py:924(record)
#      1400    0.001    0.000    0.001    0.000 {_weakref.proxy}
#       100    0.001    0.000    0.001    0.000 deviceufunc.py:16(__init__)
#       100    0.001    0.000    0.001    0.000 {numpy.core.multiarray.empty}
#      1100    0.001    0.000    0.006    0.000 dispatch.py:200(is_device_array)
#       900    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x7feb285c54c0}
#      2900    0.001    0.000    0.001    0.000 driver.py:777(device_ctypes_pointer)
#       200    0.001    0.000    0.008    0.000 copy.py:66(copy)
#      1500    0.001    0.000    0.077    0.000 {next}
#      1100    0.001    0.000    0.005    0.000 devicearray.py:22(is_cuda_ndarray)
#      1400    0.001    0.000    0.001    0.000 dummyarray.py:80(get_offset)
#       100    0.001    0.000    0.030    0.000 plugins.py:84(__call__)
#       700    0.001    0.000    0.002    0.000 <string>:8(__new__)
#       800    0.001    0.000    0.001    0.000 dummyarray.py:172(is_contig)
#       700    0.001    0.000    0.001    0.000 driver.py:664(mem_finalize)
#       600    0.001    0.000    0.003    0.000 driver.py:1272(host_memory_size)
#       100    0.001    0.000    0.007    0.000 compiler.py:111(configure)
#      1400    0.001    0.000    0.001    0.000 dummyarray.py:160(<genexpr>)
#       100    0.001    0.000    0.001    0.000 deviceufunc.py:140(get_function)
#      1200    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#       100    0.001    0.000    0.024    0.000 deviceufunc.py:130(get_arguments)
#       600    0.001    0.000    0.004    0.000 numeric.py:394(asarray)
#       100    0.001    0.000    0.084    0.001 api.py:63(device_array)
#       700    0.001    0.000    0.001    0.000 driver.py:282(add_trash)
#       700    0.001    0.000    0.001    0.000 driver.py:663(_make_mem_finalizer)
#       100    0.001    0.000    0.028    0.000 binding.py:251(generate_normal)
#       600    0.001    0.000    0.001    0.000 {min}
#       700    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#       600    0.001    0.000    0.002    0.000 driver.py:1257(host_memory_extents)
#       700    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#      1400    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#       700    0.001    0.000    0.001    0.000 driver.py:738(__del__)
#       100    0.001    0.000    0.031    0.000 dispatch.py:206(launch)
#       100    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       101    0.001    0.000    0.001    0.000 {max}
#      1400    0.001    0.000    0.001    0.000 {_ctypes.sizeof}
#       100    0.001    0.000    0.003    0.000 driver.py:1017(configure)
#       100    0.001    0.000    0.002    0.000 deviceufunc.py:91(_get_actual_args)
#      1400    0.001    0.000    0.001    0.000 {method 'popleft' of 'collections.deque' objects}
#       700    0.001    0.000    0.001    0.000 contextlib.py:12(__init__)
#      1400    0.001    0.000    0.001    0.000 dummyarray.py:104(is_contiguous)
#      1400    0.000    0.000    0.000    0.000 dummyarray.py:161(<genexpr>)
#       100    0.000    0.000    0.088    0.001 dispatch.py:209(device_array)
#       200    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       701    0.000    0.000    0.000    0.000 {_ctypes.byref}
#       100    0.000    0.000    0.000    0.000 devicearray.py:332(sentry_contiguous)
#       800    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       100    0.000    0.000    0.022    0.000 compiler.py:222(__call__)
#       100    0.000    0.000    0.000    0.000 deviceufunc.py:42(_fill_argtypes)
#       800    0.000    0.000    0.000    0.000 devicearray.py:124(_default_stream)
#       100    0.000    0.000    1.190    0.012 api.py:244(_auto_device)
#       100    0.000    0.000    0.001    0.000 compiler.py:180(get)
#       104    0.000    0.000    0.000    0.000 {range}
#       100    0.000    0.000    0.012    0.000 driver.py:1034(__call__)
#       100    0.000    0.000    0.001    0.000 plugins.py:50(forall)
#       100    0.000    0.000    0.006    0.000 compiler.py:108(copy)
#       700    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       300    0.000    0.000    0.000    0.000 stride_tricks.py:19(__init__)
#       500    0.000    0.000    0.000    0.000 deviceufunc.py:105(<lambda>)
#       206    0.000    0.000    0.000    0.000 {hasattr}
#       600    0.000    0.000    0.000    0.000 devicearray.py:217(as_cuda_arg)
#       200    0.000    0.000    0.000    0.000 copy_reg.py:92(__newobj__)
#       600    0.000    0.000    0.000    0.000 {_ctypes.addressof}
#       400    0.000    0.000    0.000    0.000 {iter}
#       200    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 plugins.py:77(__init__)
#       200    0.000    0.000    0.000    0.000 api.py:21(stream)
#         2    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#       100    0.000    0.000    0.000    0.000 {_ctypes.POINTER}
#        16    0.000    0.000    0.000    0.000 iostream.py:178(write)
#         3    0.000    0.000    0.009    0.003 _methods.py:53(_mean)
#       102    0.000    0.000    0.000    0.000 libutils.py:46(check_error)
#       300    0.000    0.000    0.000    0.000 deviceufunc.py:158(force_array_layout)
#        16    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#       100    0.000    0.000    0.000    0.000 {all}
#       100    0.000    0.000    0.000    0.000 plugins.py:63(_compute_thread_per_block)
#         4    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#        16    0.000    0.000    0.000    0.000 {method 'decode' of 'str' objects}
#       203    0.000    0.000    0.000    0.000 {id}
#        16    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        16    0.000    0.000    0.000    0.000 iostream.py:79(_is_master_process)
#         1    0.000    0.000    0.013    0.013 _methods.py:123(_std)
#        16    0.000    0.000    0.000    0.000 iostream.py:88(_check_mp_mode)
#        16    0.000    0.000    0.000    0.000 utf_8.py:15(decode)
#         1    0.000    0.000    0.000    0.000 binding.py:211(__init__)
#         5    0.000    0.000    0.000    0.000 numeric.py:464(asanyarray)
#         3    0.000    0.000    0.009    0.003 fromnumeric.py:2651(mean)
#         5    0.000    0.000    0.000    0.000 {issubclass}
#         1    0.000    0.000    0.000    0.000 finalizer.py:11(_run_finalizer)
#         1    0.000    0.000    0.000    0.000 finalizer.py:24(track)
#        18    0.000    0.000    0.000    0.000 {time.time}
#         1    0.000    0.000    0.000    0.000 api.py:66(__init__)
#         1    0.000    0.000    0.000    0.000 finalizer.py:41(_finalizer_track)
#         1    0.000
#     0.000    0.013    0.013 fromnumeric.py:2737(std)
#         1    0.000    0.000    0.000    0.000 binding.py:217(_finalize)
#        16    0.000    0.000    0.000    0.000 {posix.getpid}
#         1    0.000    0.000    0.000    0.000 libutils.py:13(__new__)
#         1    0.000    0.000    0.000    0.000 api.py:8(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
# Result
#          stock price: 22.6402514162
#       standard error: 0.000177156870874
#             paid off: 1.14025634544
#         option price: 1.04908648186
# Performance
#         Mstep/second: 41.23
#         time elapsed: 7.277s
#          166349 function calls (163049 primitive calls) in 7.331 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      4400    5.604    0.001    5.610    0.001 driver.py:212(safe_cuda_api_call)
#         1    1.136    1.136    7.276    7.276 <ipython-input-17-8c8d5e237eea>:1(montecarlo_curand)
#      1400    0.063    0.000    0.068    0.000 ndarray.py:110(make_array_ctype)
#      1405    0.052    0.000    0.052    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.026    0.026    7.324    7.324 mc.py:25(driver)
# 13200/9900    0.021    0.000    0.025    0.000 {getattr}
#       102    0.021    0.000    0.021    0.000 libutils.py:40(wrapped)
#       700    0.019    0.000    0.553    0.001 devicearray.py:55(__init__)
#       700    0.019    0.000    0.203    0.000 ndarray.py:141(ndarray_populate_head)
#       700    0.017    0.000    0.080    0.000 dummyarray.py:157(__init__)
#       700    0.014    0.000    0.205    0.000 driver.py:506(memalloc)
#      1400    0.012    0.000    0.051    0.000 fromnumeric.py:2259(prod)
#       700    0.012    0.000    0.094    0.000 ndarray.py:94(write)
#       700    0.009    0.000    0.009    0.000 utils.py:129(__setitem__)
#         1    0.007    0.007    0.013    0.013 _methods.py:77(_var)
#      2900    0.007    0.000    0.030    0.000 driver.py:1284(device_ctypes_pointer)
#       100    0.007    0.000    3.715    0.037 deviceufunc.py:165(call)
#         1    0.007    0.007    7.331    7.331 <string>:1(<module>)
#       700    0.006    0.000    0.091    0.000 dummyarray.py:148(from_desc)
#       200    0.006    0.000    2.001    0.010 devicearray.py:156(copy_to_host)
#       100    0.006    0.000    3.729    0.037 dispatch.py:25(__call__)
#      4400    0.006    0.000    0.006    0.000 driver.py:241(_check_error)
#      5426    0.006    0.000    0.006    0.000 {isinstance}
#      2101    0.005    0.000    0.020    0.000 devices.py:114(_get_device)
#       700    0.005    0.000    0.076    0.000 driver.py:669(cleanup)
#       905    0.005    0.000    0.005    0.000 {numpy.core.multiarray.array}
#      1400    0.005    0.000    0.005    0.000 ndarray.py:115(c_array)
#      1300    0.005    0.000    3.476    0.003 driver.py:1318(host_to_device)
#       700    0.005    0.000    0.016    0.000 dummyarray.py:184(_compute_extent)
#      1500    0.005    0.000    0.005    0.000 {numba.mviewbuf.memoryview_get_buffer}
#       300    0.005    0.000    0.007    0.000 stride_tricks.py:23(as_strided)
#      6200    0.005    0.000    0.011    0.000 driver.py:857(__getattr__)
#       700    0.005    0.000    0.031    0.000 ndarray.py:78(allocate)
#       700    0.005    0.000    0.007    0.000 dummyarray.py:167(_compute_layout)
#      4202    0.004    0.000    0.004    0.000 threadlocal.py:13(stack)
#       700    0.004    0.000    0.011    0.000 contextlib.py:21(__exit__)
#       600    0.004    0.000    0.471    0.001 devicearray.py:317(from_array_like)
#      2101    0.004    0.000    0.026    0.000 devices.py:122(get_context)
#       700    0.004    0.000    0.080    0.000 driver.py:285(process)
#      1400    0.004    0.000    0.017    0.000 ndarray.py:67(get_stage)
#      2300    0.004    0.000    0.030    0.000 driver.py:1279(device_pointer)
#      4800    0.004    0.000    0.016    0.000 driver.py:1290(is_device_memory)
#      2101    0.004    0.000    0.010    0.000 threadlocal.py:36(__bool__)
#       600    0.004    0.000    3.428    0.006 devicearray.py:142(copy_to_device)
#       900    0.004    0.000    0.006    0.000 devicearray.py:136(device_ctypes_pointer)
#      2300    0.003    0.000    0.003    0.000 {zip}
#       100    0.003    0.000    2.407    0.024 api.py:101(normal)
#       100    0.003    0.000    0.013    0.000 deviceufunc.py:100(_broadcast)
#       200    0.003    0.000    0.003    0.000 {method '__reduce_ex__' of 'object' objects}
#       700    0.003    0.000    0.008    0.000 driver.py:846(__del__)
#       700    0.003    0.000    0.003    0.000 driver.py:727(__init__)
#      2101    0.003    0.000    0.006    0.000 threadlocal.py:32(is_empty)
#      1500    0.003    0.000    0.009    0.000 driver.py:1246(host_pointer)
#       700    0.003    0.000    0.003    0.000 contextlib.py:82(helper)
#       700    0.003    0.000    0.003    0.000 ndarray.py:89(free)
#      1400    0.003    0.000    0.009    0.000 dummyarray.py:108(compute_index)
#       100    0.002    0.000    0.012    0.000 driver.py:1069(launch_kernel)
#       700    0.002    0.000    0.003    0.000 ndarray.py:38(__new__)
#      2900    0.002    0.000    0.013    0.000 driver.py:1301(require_device_memory)
#       100    0.002    0.000    0.009    0.000 binding.py:271(__float_or_double)
#       601    0.002    0.000    2.704    0.004 devices.py:134(_require_cuda_context)
#       100    0.002    0.000    0.006    0.000 deviceufunc.py:50(_resolve_signature)
#      2101    0.002    0.000    0.012    0.000 threadlocal.py:39(__nonzero__)
#      3701    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#      2800    0.002    0.000    0.003    0.000 dummyarray.py:109(<genexpr>)
#       100    0.002    0.000    0.005    0.000 deviceufunc.py:27(_fill_arrays)
#      2101    0.002    0.000    0.003    0.000 threadlocal.py:28(top)
#      7100    0.002    0.000    0.002    0.000 {len}
#       100    0.002    0.000    0.003    0.000 api.py:134(_fill_stride_by_order)
#       700    0.002    0.000    0.004    0.000 driver.py:1262(memory_size_from_info)
#       700    0.002    0.000    0.002    0.000 dummyarray.py:27(__init__)
#       500    0.002    0.000    2.611    0.005 dispatch.py:203(to_device)
#       700    0.002    0.000    0.002    0.000 {numba.mviewbuf.memoryview_get_extents_info}
#       100    0.002    0.000    0.002    0.000 __init__.py:498(cast)
#       700    0.002    0.000    0.005    0.000 driver.py:748(free)
#       700    0.002    0.000    0.083    0.000 service.py:18(service)
#       700    0.002    0.000    0.003    0.000 driver.py:668(core)
#       700    0.002    0.000    0.011    0.000 contextlib.py:15(__enter__)
#       700    0.002    0.000    0.005    0.000 devicearray.py:118(__del__)
#      1400    0.002    0.000    0.039    0.000 _methods.py:34(_prod)
#       700    0.002    0.000    0.002    0.000 driver.py:837(__init__)
#       200    0.002    0.000    0.003    0.000 copy.py:306(_reconstruct)
#       700    0.002    0.000    0.004    0.000 driver.py:745(own)
#       600    0.002    0.000    0.002    0.000 {numba.mviewbuf.memoryview_get_extents}
#       200    0.002    0.000    1.994    0.010 driver.py:1336(device_to_host)
#       700    0.002    0.000    1.306    0.002 devicearray.py:338(auto_device)
#       100    0.002    0.000    0.022    0.000 compiler.py:247(_kernel_call)
#       500    0.002    0.000    2.599    0.005 api.py:23(to_device)
#      1400    0.002    0.000    0.005    0.000 {sum}
#      2101    0.002    0.000    0.002    0.000 devices.py:77(context)
#       700    0.002    0.000    0.007    0.000 driver.py:910(query)
#       100    0.001    0.000    0.005    0.000 api.py:121(_prepare_shape_strides_dtype)
#       600    0.001    0.000    0.003    0.000 compiler.py:298(_prepare_args)
#       100    0.001    0.000    0.001    0.000 api.py:32(_require_array)
#       100    0.001    0.000    0.002    0.000 deviceufunc.py:16(__init__)
#       700    0.001    0.000    0.005    0.000 driver.py:1308(device_memory_depends)
#      1400    0.001    0.000    0.001    0.000 {_weakref.proxy}
#       100    0.001    0.000    0.001    0.000 {numpy.core.multiarray.empty}
#      1100    0.001    0.000    0.006    0.000 dispatch.py:200(is_device_array)
#      2900    0.001    0.000    0.001    0.000 driver.py:777(device_ctypes_pointer)
#      1500    0.001    0.000    0.082    0.000 {next}
#       900    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x7feb285c54c0}
#       700    0.001    0.000    0.005    0.000 driver.py:924(record)
#       200    0.001    0.000    0.008    0.000 copy.py:66(copy)
#      1100    0.001    0.000    0.005    0.000 devicearray.py:22(is_cuda_ndarray)
#      1400    0.001    0.000    0.001    0.000 dummyarray.py:80(get_offset)
#       700    0.001    0.000    0.002    0.000 <string>:8(__new__)
#       100    0.001    0.000    0.031    0.000 plugins.py:84(__call__)
#       800    0.001    0.000    0.001    0.000 dummyarray.py:172(is_contig)
#       600    0.001    0.000    0.003    0.000 driver.py:1272(host_memory_size)
#       100    0.001    0.000    0.007    0.000 compiler.py:111(configure)
#       700    0.001    0.000    0.001    0.000 driver.py:664(mem_finalize)
#       100    0.001    0.000    0.001    0.000 deviceufunc.py:140(get_function)
#      1200    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#       100    0.001    0.000    0.091    0.001 api.py:63(device_array)
#       100    0.001    0.000    0.027    0.000 deviceufunc.py:130(get_arguments)
#      1400    0.001    0.000    0.001    0.000 dummyarray.py:160(<genexpr>)
#       600    0.001    0.000    0.005    0.000 numeric.py:394(asarray)
#       700    0.001    0.000    0.001    0.000 driver.py:282(add_trash)
#       100    0.001    0.000    0.030    0.000 binding.py:251(generate_normal)
#       600    0.001    0.000    0.001    0.000 {min}
#       700    0.001    0.000    0.001    0.000 driver.py:663(_make_mem_finalizer)
#       700    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#       100    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       700    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#      1400    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#       600    0.001    0.000    0.002    0.000 driver.py:1257(host_memory_extents)
#       700    0.001    0.000    0.001    0.000 driver.py:738(__del__)
#       100    0.001    0.000    0.032    0.000 dispatch.py:206(launch)
#       101    0.001    0.000    0.001    0.000 {max}
#      1400    0.001    0.000    0.001    0.000 {_ctypes.sizeof}
#       100    0.001    0.000    0.095    0.001 dispatch.py:209(device_array)
#       100    0.001    0.000    0.002    0.000 deviceufunc.py:91(_get_actual_args)
#      1400    0.001    0.000    0.001    0.000 dummyarray.py:104(is_contiguous)
#       700    0.001    0.000    0.001    0.000 contextlib.py:12(__init__)
#       100    0.001    0.000    0.001    0.000 devicearray.py:332(sentry_contiguous)
#       701    0.001    0.000    0.001    0.000 {_ctypes.byref}
#       100    0.001    0.000    0.003    0.000 driver.py:1017(configure)
#      1400    0.001    0.000    0.001    0.000 dummyarray.py:161(<genexpr>)
#       200    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       100    0.000    0.000    0.000    0.000 deviceufunc.py:42(_fill_argtypes)
#       100    0.000    0.000    1.305    0.013 api.py:244(_auto_device)
#       800    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       800    0.000    0.000    0.000    0.000 devicearray.py:124(_default_stream)
#       100    0.000    0.000    0.023    0.000 compiler.py:222(__call__)
#       104    0.000    0.000    0.000    0.000 {range}
#      1400    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#       100    0.000    0.000    0.001    0.000 compiler.py:180(get)
#       700    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       500    0.000    0.000    0.000    0.000 deviceufunc.py:105(<lambda>)
#       100    0.000    0.000    0.013    0.000 driver.py:1034(__call__)
#       100    0.000    0.000    0.001    0.000 plugins.py:50(forall)
#       100    0.000    0.000    0.006    0.000 compiler.py:108(copy)
#       300    0.000    0.000    0.000    0.000 stride_tricks.py:19(__init__)
#       206    0.000    0.000    0.000    0.000 {hasattr}
#       200    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       600    0.000    0.000    0.000    0.000 {_ctypes.addressof}
#       600    0.000    0.000    0.000    0.000 devicearray.py:217(as_cuda_arg)
#       200    0.000    0.000    0.000    0.000 copy_reg.py:92(__newobj__)
#       200    0.000    0.000    0.000    0.000 api.py:21(stream)
#       100    0.000    0.000    0.000    0.000 plugins.py:77(__init__)
#       400    0.000    0.000    0.000    0.000 {iter}
#       100    0.000    0.000    0.000    0.000 {_ctypes.POINTER}
#         2    0.000    0.000    0.000    0.000 {numpy.core.multiarray.zeros}
#        16    0.000    0.000    0.000    0.000 iostream.py:178(write)
#         3    0.000    0.000    0.009    0.003 _methods.py:53(_mean)
#       102    0.000    0.000    0.000    0.000 libutils.py:46(check_error)
#       300    0.000    0.000    0.000    0.000 deviceufunc.py:158(force_array_layout)
#        16    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#       100    0.000    0.000    0.000    0.000 {all}
#       203    0.000    0.000    0.000    0.000 {id}
#       100    0.000    0.000    0.000    0.000 plugins.py:63(_compute_thread_per_block)
#        16    0.000    0.000    0.000    0.000 {method 'decode' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#        16    0.000    0.000    0.000    0.000 iostream.py:79(_is_master_process)
#        16    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.013    0.013 _methods.py:123(_std)
#        16    0.000    0.000    0.000    0.000 utf_8.py:15(decode)
#         5    0.000    0.000    0.000    0.000 numeric.py:464(asanyarray)
#         3    0.000    0.000    0.009    0.003 fromnumeric.py:2651(mean)
#        16    0.000    0.000    0.000    0.000 iostream.py:88(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 finalizer.py:11(_run_finalizer)
#         1    0.000    0.000    0.000    0.000 binding.py:211(__init__)
#        18    0.000    0.000    0.000    0.000 {time.time}
#         5    0.000    0.000    0.000    0.000 {issubclass}
#         1    0.000    0.000    0.000    0.000 finalizer.py:24(track)
#         1    0.000    0.000    0.000    0.000 api.py:66(__init__)
#         1    0.000    0.000    0.000    0.000 finalizer.py:41(_finalizer_track)
#        16    0.000    0.000    0.000    0.000 {posix.getpid}
#         1    0.000    0.000    0.013    0.013 fromnumeric.py:2737(std)
#         1    0.000    0.000    0.000    0.000 binding.py:217(_finalize)
#         1    0.000    0.000    0.000    0.000 api.py:8(__init__)
#         1    0.000    0.000    0.000    0.000 libutils.py:13(__new__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# At this point, the top time consuming areas are the host_to_device and device_to_host function calls.  This is the PCI-Express data movement we originally thought was the top culprit.  We can now look at optimizing these areas, and this will be your goal for Task #2.
#
# ### Task #2
#
# In this task, we will make use of the CUDA Runtime library to optimize some data movement between the host (CPU) and the device (GPU).  The first thing we need to is import this library into our runspace - we can do this by executing the next cell.

# %%
from numbapro import cuda

# %% [markdown]
# **IMPORTANT NOTE:** Once you start manually managing the data involved in a `'gpu'` targeted vectorized function such as our `step` function, the NumbaPro compiler assumes you'll be handling **ALL** of the device data movement.  This means any variables of type `DeviceNDArray` passed in to or returned from the `step` function need to be explicitly passed between the host and GPU using CUDA Runtime API calls.  So while we will be optimizing our `montecarlo` function in stages, we won't be able to actually test these stages until the very end.
#
# ### Generate and Leave Random Noise Values on the GPU
#
# The first source of excessive data movement across the PCI-Express bus we are going to fix is the generation of the `noises` data.  The current process is this:
#
# 1. Call `prng.normal` to generate the random data
# 2. The cuRAND library uses the GPU to generate the data which is temporarily stored on the GPU
# 3. The library then copies the data from the GPU to the host copy of `noises`
# 4. When the `montecarlo` function calls the GPU-accelerated `step` function, the `noises` data is passed *back* across the PCIE bus to be used on the GPU
#
# So we have two excessive copies of `NumPaths` worth of data across the PCI-Express bus.  Let's fix that.  The [documentation](http://docs.continuum.io/numbapro/cudalib.html) for cuRAND says the prng.normal function can accept either a host or a device array.  So the new process needed is this:
#
# 1. Allocate an empty `DeviceNDArray` on the GPU using the `cuda.device_array` API call (see the [documentation](http://docs.continuum.io/numbapro/CUDAJit.html#memory-transfer)).
# 2. Change the `prng.normal` call to accept this new array.
# 3. Modify the `step` funtion call to use this device side array.
#
# Perform these steps in the below cell and execute the cell to check for syntax errors.  If you get stuck, you can look ahead to the next section as the work has been completed there.
#
# **TIP:** It's good practice to precede the variable name of any device-side arrays with `d_`

# %%
def montecarlo_datamgmt(paths, dt, interest, volatility):
    c0 = interest - 0.5 * volatility ** 2
    c1 = volatility * np.sqrt(dt)

    prng = curand.PRNG(rndtype=curand.PRNG.XORWOW)
    d_noises = np.zeros(paths.shape[0], dtype=float)
    d_curLast = cuda.to_device(paths[:,0]) # Copiando los datos paths a la gpu.
    d_curNext = cuda.device_array(paths.shape[0]) # Crea un array de datos basios para la primera iteracion.

    for j in xrange(1, paths.shape[1]):   # for each time step
        prices = paths[:, j - 1]          # last set of prices
        # Generate gaussian noises for simulation
        prng.normal(noises, 0., 1.)
         # Call the GPU-acclereated step function to calculate the next set of prices
        d_curNext = step(d_curLast, dt, c0, c1, d_noises)
        # Copy calculated prices to host
        d_curNext.copy_to_host(paths[:,j])
        # Swap the prices so the "last" prices was the one we just copied 
        # to the host.
        d_curNext, d_curLast = d_curLast, d_curNext

        # Call the GPU-acclereated step function to calculate the next set of prices
        paths[:, j] = step(prices, dt, c0, c1, noises)

# %% [markdown]
# ### Optimize current and generated `prices` Data Transfers
#
# The next data transfers to optimize has to do with sending the current set of stock prices to the GPU and returning the calculated set of next prices back to the host.  This is the current process:
#
# 1. Within the `for` loop, we set `prices` equal to the current or known set of stock prices, which is stored in `paths[:, j - 1]`
# 2. The `prices` array is then sent to the GPU when the `step` function is called
# 3. The GPU executes the `step` function and generates the next set of stock prices
# 4. This new set of stock prices is then transferred back to the host and stored in `paths[:, j]`
# 5. The `for` loop starts over and the next set of stock prices, which we just copied from the GPU->host, becomes our current set of stock prices and are then transferred **back** to the GPU and the process repeats
#
# So in this process, we have an extra transfer of `NumPaths` number of price data across the PCIE bus in all but the first time through the `for` loop.  When we call `step` to generate the new stock prices, the data is already on the GPU, so we can optimize by using this data instead of having to re-copy it back from the host each time.
#
# There are a few ways to do this, see what you can come up with by modifying the cell below.  If done correctly, this will be the final step in optimizing the data transfers in our `montecarlo_datamgmt` function.  So when you are done, you can execute the function and see if you get the correct results.  There are hints provided as well as the final answer hidden below the cell.
#
# <p class="hint_trigger">Hint #1
#     <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight">You can swap two variables in Python quickly with <code>x, y = y, x</code></div></div></div></p>
#
# <p class="hint_trigger">Hint #2
#     <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight">The <code>step</code> function call should only work with device arrays, it should not reference the <code>paths</code> array either in its arguments or in what it returns</div></div></div></p>

# %%
def montecarlo_datamgmt(paths, dt, interest, volatility):
    c0 = interest - 0.5 * volatility ** 2
    c1 = volatility * np.sqrt(dt)

    prng = curand.PRNG(rndtype=curand.PRNG.XORWOW)
    d_noises = np.zeros(paths.shape[0], dtype=float)
    d_curLast = cuda.to_device(paths[:,0]) # Copiando los datos paths a la gpu.
    d_curNext = cuda.device_array(paths.shape[0]) # Crea un array de datos basios para la primera iteracion.

    for j in xrange(1, paths.shape[1]):   # for each time step
        prices = paths[:, j - 1]          # last set of prices
        # Generate gaussian noises for simulation
        prng.normal(d_noises, 0., 1.)
         # Call the GPU-acclereated step function to calculate the next set of prices
        d_curNext = step(d_curLast, dt, c0, c1, d_noises)
        # Copy calculated prices to host
        d_curNext.copy_to_host(paths[:,j])
        # Swap the prices so the "last" prices was the one we just copied 
        # to the host.
        d_curNext, d_curLast = d_curLast, d_curNext

        # Call the GPU-acclereated step function to calculate the next set of prices
        paths[:, j] = step(prices, dt, c0, c1, d_noises)
driver(montecarlo_datamgmt, do_plot=True)
# Out:
# Result
#          stock price: 22.6402514162
#       standard error: 0.000177156870874
#             paid off: 1.14025634544
#         option price: 1.04908648186
# Performance
#         Mstep/second: 31.06
#         time elapsed: 9.660s
# Plotting 50/3000000 paths

# %% [markdown]
# <p class="hint_trigger">Click to check your answer
# <div class="toggle_container"><div class="input_area box-flex1"><div class="highlight"><pre><code>def montecarlo_datamgmt(paths, dt, interest, volatility):
#     c0 = interest - 0.5 &#42; volatility ** 2
#     c1 = volatility &#42; np.sqrt(dt)
#
#     prng = curand.PRNG(rndtype=curand.PRNG.XORWOW)
#     d_noises = cuda.device_array(paths.shape[0])
#
#     d_curLast = cuda.to_device(paths[:,0]) # Copy first set of stock prices to the GPU
#     d_curNext = cuda.device_array(paths.shape[0]) # Create an empty array to hold the next set of calculated prices
#
#     for j in xrange(1, paths.shape[1]):   # for each time step
#         # Generate gaussian noises for simulation
#         prng.normal(d_noises, 0., 1.)
#         # Call the GPU-acclereated step function to calculate the next set of prices
#         d_curNext = step(d_curLast, dt, c0, c1, d_noises)
#         # Copy calculated prices to host
#         d_curNext.copy_to_host(paths[:,j])
#         # Swap the prices so the "last" prices was the one we just copied
#         # to the host.
#         d_curNext, d_curLast = d_curLast, d_curNext</code></pre></div></div></div></p>

# %% [markdown]
# Once you have successfully got the new `montecarlo_datamgmt` function working, you can profile it below and see what our optimizations have achieved.

# %%
import cProfile as profiler
profiler.run("driver(montecarlo_datamgmt)", sort="time")
# Out:
# Result
#          stock price: 22.6402514162
#       standard error: 0.000177156870874
#             paid off: 1.14025634544
#         option price: 1.04908648186
# Performance
#         Mstep/second: 31.50
#         time elapsed: 9.524s
#          304111 function calls (297705 primitive calls) in 9.576 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      7811    7.832    0.001    7.841    0.001 driver.py:212(safe_cuda_api_call)
#         1    0.807    0.807    9.523    9.523 <ipython-input-31-5923060c9fec>:1(montecarlo_datamgmt)
#      2604    0.111    0.000    0.120    0.000 ndarray.py:110(make_array_ctype)
#      2609    0.072    0.000    0.072    0.000 {method 'reduce' of 'numpy.ufunc' objects}
# 24819/18413    0.035    0.000    0.042    0.000 {getattr}
#      1302    0.034    0.000    0.487    0.000 ndarray.py:141(ndarray_populate_head)
#      1202    0.034    0.000    0.326    0.000 driver.py:506(memalloc)
#      1302    0.033    0.000    1.051    0.001 devicearray.py:55(__init__)
#      1302    0.027    0.000    0.128    0.000 dummyarray.py:157(__init__)
#         1    0.025    0.025    9.570    9.570 mc.py:25(driver)
#       102    0.020    0.000    0.021    0.000 libutils.py:40(wrapped)
#      1302    0.020    0.000    0.295    0.000 ndarray.py:94(write)
#      2604    0.019    0.000    0.082    0.000 fromnumeric.py:2259(prod)
#      5205    0.012    0.000    0.050    0.000 driver.py:1284(device_ctypes_pointer)
#       200    0.011    0.000    5.332    0.027 deviceufunc.py:165(call)
#      1302    0.010    0.000    0.144    0.000 dummyarray.py:148(from_desc)
#      1805    0.010    0.000    0.010    0.000 {numpy.core.multiarray.array}
#     10335    0.010    0.000    0.010    0.000 {isinstance}
#       600    0.010    0.000    0.015    0.000 stride_tricks.py:23(as_strided)
#      3807    0.009    0.000    0.035    0.000 devices.py:114(_get_device)
#       200    0.009    0.000    5.354    0.027 dispatch.py:25(__call__)
#      7811    0.009    0.000    0.009    0.000 driver.py:241(_check_error)
#      2604    0.009    0.000    0.009    0.000 ndarray.py:115(c_array)
#      1202    0.009    0.000    0.119    0.000 driver.py:669(cleanup)
#     11611    0.009    0.000    0.020    0.000 driver.py:857(__getattr__)
#      2303    0.009    0.000    4.588    0.002 driver.py:1318(host_to_device)
#      1302    0.009    0.000    0.028    0.000 dummyarray.py:184(_compute_extent)
#      1302    0.008    0.000    0.021    0.000 contextlib.py:21(__exit__)
#      2603    0.008    0.000    0.008    0.000 {numba.mviewbuf.memoryview_get_buffer}
#      1302    0.008    0.000    0.056    0.000 ndarray.py:78(allocate)
#      1302    0.007    0.000    0.011    0.000 dummyarray.py:167(_compute_layout)
#      3807    0.007    0.000    0.044    0.000 devices.py:122(get_context)
#         1    0.007    0.007    0.013    0.013 _methods.py:77(_var)
#      7614    0.007    0.000    0.007    0.000 threadlocal.py:13(stack)
#      1202    0.007    0.000    0.007    0.000 utils.py:129(__setitem__)
#      2604    0.007    0.000    0.030    0.000 ndarray.py:67(get_stage)
#       300    0.007    0.000    3.041    0.010 devicearray.py:156(copy_to_host)
#      1202    0.006    0.000    0.126    0.000 driver.py:285(process)
#         1    0.006    0.006    9.576    9.576 <string>:1(<module>)
#       200    0.006    0.000    0.025    0.000 deviceufunc.py:100(_broadcast)
#      3807    0.006    0.000    0.016    0.000 threadlocal.py:36(__bool__)
#      8706    0.006    0.000    0.027    0.000 driver.py:1290(is_device_memory)
#      4005    0.006    0.000    0.048    0.000 driver.py:1279(device_pointer)
#       400    0.006    0.000    0.006    0.000 {method '__reduce_ex__' of 'object' objects}
#      4306    0.006    0.000    0.006    0.000 {zip}
#      1001    0.006    0.000    4.374    0.004 devicearray.py:142(copy_to_device)
#      1001    0.006    0.000    0.696    0.001 devicearray.py:317(from_array_like)
#       200    0.005    0.000    0.024    0.000 driver.py:1069(launch_kernel)
#      1302    0.005    0.000    0.006    0.000 contextlib.py:82(helper)
#      3807    0.005    0.000    0.010    0.000 threadlocal.py:32(is_empty)
#      2604    0.005    0.000    0.016    0.000 dummyarray.py:108(compute_index)
#      1202    0.005    0.000    0.005    0.000 driver.py:727(__init__)
#      1401    0.004    0.000    0.008    0.000 devicearray.py:136(device_ctypes_pointer)
#      2603    0.004    0.000    0.015    0.000 driver.py:1246(host_pointer)
#       200    0.004    0.000    0.011    0.000 deviceufunc.py:27(_fill_arrays)
#      5205    0.004    0.000    0.022    0.000 driver.py:1301(require_device_memory)
#      1302    0.004    0.000    0.005    0.000 ndarray.py:38(__new__)
#      1202    0.004    0.000    0.011    0.000 driver.py:846(__del__)
#       201    0.004    0.000    0.005    0.000 api.py:134(_fill_stride_by_order)
#       200    0.004    0.000    0.010    0.000 deviceufunc.py:50(_resolve_signature)
#      3807    0.004    0.000    0.020    0.000 threadlocal.py:39(__nonzero__)
#      5208    0.004    0.000    0.006    0.000 dummyarray.py:109(<genexpr>)
#      1103    0.004    0.000    4.044    0.004 devices.py:134(_require_cuda_context)
#     13315    0.004    0.000    0.004    0.000 {len}
#      7105    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#      3807    0.003    0.000    0.005    0.000 threadlocal.py:28(top)
#      1302    0.003    0.000    0.004    0.000 ndarray.py:89(free)
#       400    0.003    0.000    0.006    0.000 copy.py:306(_reconstruct)
#       200    0.003    0.000    0.044    0.000 compiler.py:247(_kernel_call)
#      1202    0.003    0.000    0.007    0.000 driver.py:1262(memory_size_from_info)
#      1302    0.003    0.000    0.003    0.000 dummyarray.py:27(__init__)
#         2    0.003    0.002    0.003    0.002 {numpy.core.multiarray.zeros}
#       100    0.003    0.000    2.235    0.022 api.py:101(normal)
#      2604    0.003    0.000    0.062    0.000 _methods.py:34(_prod)
#       900    0.003    0.000    3.837    0.004 dispatch.py:203(to_device)
#      2604    0.003    0.000    0.009    0.000 {sum}
#      1202    0.003    0.000    0.007    0.000 driver.py:745(own)
#      1202    0.003    0.000    0.130    0.000 service.py:18(service)
#       200    0.003    0.000    0.003    0.000 deviceufunc.py:16(__init__)
#      1202    0.003    0.000    0.003    0.000 {numba.mviewbuf.memoryview_get_extents_info}
#       201    0.003    0.000    0.009    0.000 api.py:121(_prepare_shape_strides_dtype)
#      1302    0.003    0.000    0.013    0.000 driver.py:910(query)
#      1202    0.003    0.000    0.003    0.000 driver.py:837(__init__)
#      1001    0.003    0.000    0.003    0.000 {numba.mviewbuf.memoryview_get_extents}
#       901    0.003    0.000    3.832    0.004 api.py:23(to_device)
#      1200    0.003    0.000    0.006    0.000 compiler.py:298(_prepare_args)
#      1202    0.003    0.000    0.007    0.000 driver.py:748(free)
#      1202    0.003    0.000    0.004    0.000 driver.py:668(core)
#      3807    0.003    0.000    0.003    0.000 devices.py:77(context)
#      1302    0.002    0.000    0.020    0.000 contextlib.py:15(__enter__)
#      1302    0.002    0.000    0.007    0.000 devicearray.py:118(__del__)
#      1302    0.002    0.000    0.009    0.000 driver.py:1308(device_memory_depends)
#       300    0.002    0.000    3.033    0.010 driver.py:1336(device_to_host)
#       100    0.002    0.000    0.008    0.000 binding.py:271(__float_or_double)
#      1302    0.002    0.000    0.009    0.000 driver.py:924(record)
#       400    0.002    0.000    0.016    0.000 copy.py:66(copy)
#      2300    0.002    0.000    0.010    0.000 dispatch.py:200(is_device_array)
#      5205    0.002    0.000    0.002    0.000 driver.py:777(device_ctypes_pointer)
#      1300    0.002    0.000    1.246    0.001 devicearray.py:338(auto_device)
#      2300    0.002    0.000    0.008    0.000 devicearray.py:22(is_cuda_ndarray)
#      2404    0.002    0.000    0.002    0.000 {_weakref.proxy}
#      1702    0.002    0.000    0.002    0.000 {built-in method __new__ of type object at 0x7feb285c54c0}
#       200    0.002    0.000    0.060    0.000 plugins.py:84(__call__)
#       200    0.002    0.000    0.014    0.000 compiler.py:111(configure)
#      2606    0.002    0.000    0.128    0.000 {next}
#      2604    0.002    0.000    0.002    0.000 dummyarray.py:80(get_offset)
#       100    0.002    0.000    0.002    0.000 __init__.py:498(cast)
#      1302    0.002    0.000    0.003    0.000 <string>:8(__new__)
#      1200    0.002    0.000    0.009    0.000 numeric.py:394(asarray)
#       201    0.002    0.000    0.190    0.001 api.py:63(device_array)
#      1404    0.002    0.000    0.002    0.000 dummyarray.py:172(is_contig)
#       200    0.002    0.000    0.002    0.000 deviceufunc.py:140(get_function)
#      1202    0.002    0.000    0.002    0.000 driver.py:664(mem_finalize)
#       200    0.002    0.000    0.052    0.000 deviceufunc.py:130(get_arguments)
#      2302    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      1001    0.001    0.000    0.005    0.000 driver.py:1272(host_memory_size)
#       100    0.001    0.000    0.001    0.000 api.py:32(_require_array)
#      2604    0.001    0.000    0.001    0.000 dummyarray.py:160(<genexpr>)
#      1202    0.001    0.000    0.001    0.000 driver.py:663(_make_mem_finalizer)
#      1302    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#      1202    0.001    0.000    0.001    0.000 {method 'pop' of 'list' objects}
#       200    0.001    0.000    0.062    0.000 dispatch.py:206(launch)
#      2604    0.001    0.000    0.001    0.000 {method 'append' of 'collections.deque' objects}
#      1202    0.001    0.000    0.001    0.000 driver.py:738(__del__)
#       201    0.001    0.000    0.002    0.000 {max}
#      1202    0.001    0.000    0.002    0.000 driver.py:282(add_trash)
#       200    0.001    0.000    0.197    0.001 dispatch.py:209(device_array)
#      1001    0.001    0.000    0.001    0.000 {min}
#       200    0.001    0.000    0.006    0.000 driver.py:1017(configure)
#       200    0.001    0.000    0.004    0.000 deviceufunc.py:91(_get_actual_args)
#      2604    0.001    0.000    0.001    0.000 {_ctypes.sizeof}
#       400    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#      1302    0.001    0.000    0.001    0.000 contextlib.py:12(__init__)
#      1001    0.001    0.000    0.004    0.000 driver.py:1257(host_memory_extents)
#       200    0.001    0.000    0.001    0.000 deviceufunc.py:42(_fill_argtypes)
#      2604    0.001    0.000    0.001    0.000 dummyarray.py:104(is_contiguous)
#      2604    0.001    0.000    0.001    0.000 dummyarray.py:161(<genexpr>)
#       200    0.001    0.000    0.044    0.000 compiler.py:222(__call__)
#      1203    0.001    0.000    0.001    0.000 {_ctypes.byref}
#       205    0.001    0.000    0.001    0.000 {range}
#      2604    0.001    0.000    0.001    0.000 {method 'popleft' of 'collections.deque' objects}
#      1502    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#       100    0.001    0.000    0.001    0.000 {numpy.core.multiarray.empty}
#       200    0.001    0.000    0.003    0.000 compiler.py:180(get)
#      1301    0.001    0.000    0.001    0.000 devicearray.py:124(_default_stream)
#       100    0.001    0.000    0.029    0.000 binding.py:251(generate_normal)
#       200    0.001    0.000    0.025    0.000 driver.py:1034(__call__)
#       600    0.001    0.000    0.001    0.000 stride_tricks.py:19(__init__)
#       100    0.001    0.000    0.182    0.002 devicearray.py:230(reshape)
#       100    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       200    0.001    0.000    0.011    0.000 compiler.py:108(copy)
#      1000    0.001    0.000    0.001    0.000 deviceufunc.py:105(<lambda>)
#       200    0.001    0.000    0.001    0.000 plugins.py:50(forall)
#       406    0.001    0.000    0.001    0.000 {hasattr}
#      1302    0.001    0.000    0.001    0.000 {method 'discard' of 'set' objects}
#      1200    0.000    0.000    0.000    0.000 devicearray.py:217(as_cuda_arg)
#       100    0.000    0.000    0.000    0.000 devicearray.py:332(sentry_contiguous)
#       100    0.000    0.000    1.244    0.012 api.py:244(_auto_device)
#       400    0.000    0.000    0.001    0.000 copy_reg.py:92(__newobj__)
#       400    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#      1200    0.000    0.000    0.000    0.000 {_ctypes.addressof}
#       200    0.000    0.000    0.000    0.000 plugins.py:77(__init__)
#       702    0.000    0.000    0.000    0.000 {iter}
#       200    0.000    0.000    0.000    0.000 api.py:21(stream)
#       100    0.000    0.000    0.000    0.000 {_ctypes.POINTER}
#       600    0.000    0.000    0.000    0.000 deviceufunc.py:158(force_array_layout)
#       200    0.000    0.000    0.000    0.000 {all}
#       100    0.000    0.000    0.001    0.000 driver.py:1232(device_memory_size)
#       403    0.000    0.000    0.000    0.000 {id}
#        16    0.000    0.000    0.000    0.000 iostream.py:178(write)
#       200    0.000    0.000    0.000    0.000 plugins.py:63(_compute_thread_per_block)
#         3    0.000    0.000    0.008    0.003 _methods.py:53(_mean)
#       102    0.000    0.000    0.000    0.000 libutils.py:46(check_error)
#        16    0.000    0.000    0.000    0.000 {_codecs.utf_8_decode}
#        16    0.000    0.000    0.000    0.000 {method 'decode' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 _methods.py:43(_count_reduce_items)
#        16    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        16    0.000    0.000    0.000    0.000 iostream.py:88(_check_mp_mode)
#        16    0.000    0.000    0.000    0.000 utf_8.py:15(decode)
#         1    0.000    0.000    0.000    0.000 binding.py:211(__init__)
#         3    0.000    0.000    0.008    0.003 fromnumeric.py:2651(mean)
#        16    0.000    0.000    0.000    0.000 iostream.py:79(_is_master_process)
#         5    0.000    0.000    0.000    0.000 numeric.py:464(asanyarray)
#         1    0.000    0.000    0.013    0.013 _methods.py:123(_std)
#         1    0.000    0.000    0.000    0.000 finalizer.py:24(track)
#         1    0.000    0.000    0.000    0.000 api.py:66(__init__)
#         1    0.000    0.000    0.000    0.000 finalizer.py:11(_run_finalizer)
#        18    0.000    0.000    0.000    0.000 {time.time}
#         5    0.000    0.000    0.000    0.000 {issubclass}
#        16    0.000    0.000    0.000    0.000 {posix.getpid}
#         1    0.000    0.000    0.000    0.000 finalizer.py:41(_finalizer_track)
#         1    0.000    0.000    0.013    0.013 fromnumeric.py:2737(std)
#         1    0.000    0.000    0.000    0.000 binding.py:217(_finalize)
#         1    0.000    0.000    0.000    0.000 api.py:8(__init__)
#         1    0.000    0.000    0.000    0.000 libutils.py:13(__new__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# At this point, using only host side library calls (cuRAND, and CUDA Runtime) - we did not write any GPU-side CUDA Python code - my system showed a 23x speedup over the pure single-threaded CPU version using NumPy.  This is even more impressive when you consider this simple Monte Carlo pricer is very computationally light and barley makes use of the massive parallel power of the GPU.  All of this and we only added or modified less than 10 lines of code.
#
# In addition, there are further optimizations to be had in this application.  Such as overlapping memory transfers and computations and running concurrent kernels on the GPU at the same time - like generating the next set of `noises` data concurrently with the GPU calculating the next set of stock prices.

# %% [markdown]
# Finally, if you wish to see the supporting functions used in this lab to run the Monte Carlo simulation, just execute the cell below.

# %%
# %load mc.py

# %%
import numpy as np                         # numpy namespace
from timeit import default_timer as timer  # for timing
from matplotlib import pyplot              # for plotting
import math
from numbapro import vectorize

@vectorize(['float64(float64, float64, float64, float64, float64)'], target='gpu')
def step(price, dt, c0, c1, noise):
    return price * math.exp(c0 * dt + c1 * noise)

# Stock information parameters
StockPrice = 20.83
StrikePrice = 21.50
Volatility = 0.021
InterestRate = 0.20
Maturity = 5. / 12.

# monte-carlo simulation parameters
NumPath = 3000000
NumStep = 100

# plotting
MAX_PATH_IN_PLOT = 50

def driver(pricer, do_plot=False):
    paths = np.zeros((NumPath, NumStep + 1), order='F')
    paths[:, 0] = StockPrice
    DT = Maturity / NumStep

    ts = timer()
    pricer(paths, DT, InterestRate, Volatility)
    te = timer()
    elapsed = te - ts

    ST = paths[:, -1]
    PaidOff = np.maximum(paths[:, -1] - StrikePrice, 0)
    print 'Result'
    fmt = '%20s: %s'
    print fmt % ('stock price', np.mean(ST))
    print fmt % ('standard error', np.std(ST) / np.sqrt(NumPath))
    print fmt % ('paid off', np.mean(PaidOff))
    optionprice = np.mean(PaidOff) * np.exp(-InterestRate * Maturity)
    print fmt % ('option price', optionprice)

    print 'Performance'
    NumCompute = NumPath * NumStep
    print fmt % ('Mstep/second', '%.2f' % (NumCompute / elapsed / 1e6))
    print fmt % ('time elapsed', '%.3fs' % (te - ts))
    
    if do_plot:
        pathct = min(NumPath, MAX_PATH_IN_PLOT)
        for i in xrange(pathct):
            pyplot.plot(paths[i])
        print 'Plotting %d/%d paths' % (pathct, NumPath)
        pyplot.show()

# %% [markdown]
# ## Learn More
#
# If you are interested in learning more, you can use the following resources:
#
# * Learn more at the [CUDA Developer Zone](https://developer.nvidia.com/category/zone/cuda-zone).
# * Install [Anaconda Accelerate](https://store.continuum.io/cshop/accelerate/) from Continuum Analytics.  You can also watch the [CUDACast](http://www.youtube.com/watch?v=jKV1m8APttU) on this process.
# * Take the fantastic online and **free** Udacity [Intro to Parallel Programming](https://www.udacity.com/course/cs344) course which uses CUDA C.
# * Search or ask questions on [Stackoverflow](http://stackoverflow.com/questions/tagged/cuda) using the cuda tag

# %% [markdown]
# <a id="post-lab"></a>
# ## Post-Lab
#
# Finally, don't forget to save your work from this lab before time runs out and the instance shuts down!!
#
# 1. Save this IPython Notebook by going to `File -> Download as -> IPython (.ipynb)` at the top of this window

# %% [markdown]
# <a id="FAQ"></a>
# ---
# # Lab FAQ
#
# Q: I'm encountering issues executing the cells, or other technical problems?<br>
# A: Please see [this](https://developer.nvidia.com/self-paced-labs-faq#Troubleshooting) infrastructure FAQ.

# %% [markdown]
# <style>
# p.hint_trigger{
#   margin-bottom:7px;
#   margin-top:-5px;
#   background:#64E84D;
# }
# .toggle_container{
#   margin-bottom:0px;
# }
# .toggle_container p{
#   margin:2px;
# }
# .toggle_container{
#   background:#f0f0f0;
#   clear: both;
#   font-size:100%;
# }
# </style>
# <script>
# $("p.hint_trigger").click(function(){
#    $(this).toggleClass("active").next().slideToggle("normal");
# });
#
# $(".toggle_container").hide();
# </script>
